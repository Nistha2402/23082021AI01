# %%
import cv2
from skimage import io
from PIL import Image
import matplotlib.pyplot as plt

# %%
image=cv2.imread("nptel pay.jpg")

# %%
cv2.imshow("Window",image)
cv2.waitKey(0)
# Out:
# -1

# %%
plt.imshow(image)

# %%
plt.figure(figsize=(6,4))
io.imshow(image)

# %%
io.imshow(image)

# %%
i4 = Image.open("nptel pay.jpg")
i4
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x18936ACAE80>

# %%
import skimage as ski

# %%
gray_ver=ski.color.rgb2gray(image)
grey_ver=ski.color.rgb2grey(image)
io.imshow(gray_ver)
io.imshow(grey_ver)
plt.imsave("gray_ver.jpg",image)
plt.imsave("grey_ver.jpg",image)
# Out:
# <ipython-input-43-840adf12f43d>:2: FutureWarning: rgb2grey is deprecated. It will be removed in version 0.19.Please use rgb2gray instead.
#   grey_ver=ski.color.rgb2grey(image)

# %%
Image.open("gray_ver.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x18936BAFBB0>

# %%
Image.open("grey_ver.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x1893B8B0D90>

# %%
from skimage import viewer
# Out:
# C:\Users\dalmi\anaconda3\lib\site-packages\skimage\viewer\utils\__init__.py:1: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   from .core import *

# %%
viewer.ImageViewer(image).show()
# Out:
# []

# %%
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
io.imshow(img_gray)

# %%
img_red_plane = image[:,:,-1]
io.imshow(img_red_plane)

# %%
img_green_plane = image[:,:,-2]
io.imshow(img_green_plane)

# %%
img_blue_plane = image[:,:,-3]
io.imshow(img_blue_plane)
